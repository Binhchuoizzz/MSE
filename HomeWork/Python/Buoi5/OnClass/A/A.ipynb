# %%
import google.generativeai as genai
from IPython.display import Markdown, display

# %%
genai.configure(api_key='AIzaSyBh7k24t58qJ-cP2AIhmQQdqVJ4MtsbVeU')
model = genai.GenerativeModel('gemini-2.0-flash-exp')


def responsellm(prompt):
    response = model.generate_content(prompt)
    return display(Markdown(response.text))


print(__name__)
# Out:
# __main__

# %%
responsellm("create example of xml")
# Out:
# Okay, let's create a few examples of XML to demonstrate its structure and usage.
#
# **Example 1: A Simple Book Catalog**
#
# This XML example represents a catalog of books.
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <bookstore>
#   <book category="fiction">
#     <title>The Hitchhiker's Guide to the Galaxy</title>
#     <author>Douglas Adams</author>
#     <year>1979</year>
#     <price>10.99</price>
#   </book>
#   <book category="science">
#     <title>A Brief History of Time</title>
#     <author>Stephen Hawking</author>
#     <year>1988</year>
#     <price>15.50</price>
#   </book>
#   <book category="programming">
#     <title>Clean Code</title>
#     <author>Robert C. Martin</author>
#     <year>2008</year>
#     <price>25.00</price>
#   </book>
# </bookstore>
# ```
#
# **Explanation:**
#
# *   **`<?xml version="1.0" encoding="UTF-8"?>`**:  This is the XML declaration. It specifies the XML version (1.0) and the character encoding (UTF-8), which is a common encoding for text.
# *   **`<bookstore>`**: This is the root element.  All other elements are contained within this element.
# *   **`<book category="fiction">`**: This is a child element of `bookstore`. It represents a single book. It has an attribute `category` with the value "fiction".
# *   **`<title>`, `<author>`, `<year>`, `<price>`**: These are child elements of the `book` element and represent specific details about the book.  They are examples of text-based content.
# *   **`</book>`, `</bookstore>`**: These are the closing tags for the `book` and `bookstore` elements, respectively.  Closing tags are mandatory in XML.
#
# **Example 2:  A Person's Contact Information**
#
# This example shows how XML can be used to store structured data like contact information.
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <person>
#   <name>
#     <firstName>Alice</firstName>
#     <lastName>Smith</lastName>
#   </name>
#   <contact>
#     <phone type="home">555-123-4567</phone>
#     <phone type="work">555-987-6543</phone>
#     <email>alice.smith@example.com</email>
#   </contact>
#   <address>
#     <street>123 Main St</street>
#     <city>Anytown</city>
#     <state>CA</state>
#     <zip>12345</zip>
#   </address>
# </person>
# ```
#
# **Explanation:**
#
# *   **Hierarchical Structure**: This example demonstrates how elements can be nested within each other to create a hierarchical structure. For example, `<name>` contains `<firstName>` and `<lastName>`.
# *   **Attributes**: The `<phone>` elements use a `type` attribute to distinguish between home and work numbers.
# *   **Text Content**: Most of the elements contain text content, like the phone numbers, name, and address details.
#
# **Example 3: Configuration Data for an Application**
#
# XML is often used for configuration files because of its structured nature.
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <application>
#   <settings>
#     <theme>dark</theme>
#     <language>en</language>
#     <autoupdate>true</autoupdate>
#     <database>
#        <server>localhost</server>
#        <port>5432</port>
#        <username>admin</username>
#     </database>
#   </settings>
# </application>
# ```
#
# **Explanation:**
#
# *   **Clear Structure**: The structure of the XML clearly separates the application settings.
# *   **Nested Settings**: The `<database>` settings are nested within the `<settings>` element.
#
# **Key Points About XML:**
#
# *   **Tags:** XML uses tags enclosed in angle brackets (`<tag>`).
# *   **Elements:** Elements are defined by a start tag (`<tag>`) and an end tag (`</tag>`), and can contain text, other elements, or attributes.
# *   **Attributes:** Attributes are name-value pairs within the start tag of an element (e.g., `<element attribute="value">`).
# *   **Hierarchical Structure:** XML documents are tree-structured, with a single root element.
# *   **Well-Formed:** XML must be well-formed, meaning it must adhere to a set of rules to ensure that the structure is correct (e.g., all start tags must have corresponding end tags).
# *   **Case-Sensitive:** XML is case-sensitive for tags and attribute names.
# *   **Human-Readable (to an extent)**: While XML is machine-readable, its structured nature makes it relatively easy for humans to understand as well.
#
# These examples provide a good starting point for understanding XML. Remember that these are simple demonstrations, and XML can be used to represent much more complex data and structures. Let me know if you have a specific type of XML you'd like to see an example of!
