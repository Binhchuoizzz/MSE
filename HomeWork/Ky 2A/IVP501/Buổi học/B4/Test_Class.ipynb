# %%
# !pip install tensorflow
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/376.0 MB 342.7 kB/s eta 0:18:16
#    ---------------------------------------- 0.5/376.0 MB 342.7 kB/s eta 0:18:16
#    ---------------------------------------- 0.5/376.0 MB 342.7 kB/s eta 0:18:16
# ...

# %%
import tensorflow as tf
fashion_mnist=tf.keras.datasets.fastion_mnist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow as tf
#       2 fashion_mnist=tf.keras.datasets.fastion_mnist
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(train_image, Train_labels),(test_images, test_labels) = fashion_mnist.load_data()

# %%
imp
