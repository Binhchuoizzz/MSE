# %%
import cv2
img = cv2.imread('E:/1. Lectures/2. CPV301-Computer Vision/3. Ipynb/images/motorbike.jpg')

# %%
img2= img.copy()
img2[:,:,0]=0
img2[:,:,2]=0

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
events = [i for i in dir(cv2) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
import numpy as np
import cv2
image = np.ones((1080,1920,3),dtype = np.uint8)*255
cv2.imshow('White background', img)
#cv2.imwrite('White bg.png',img)
cv2.waitKey()
# Out:
# -1

# %%
def draw_rectangle(event, x, y, flags, param):
    global rect_start, rect_end, drawing, image, rect_coords
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        rect_start = (x,y)
    elif event ==cv2.EVENT_MOUSEMOVE:
        if drawing:
            image_copy = image.copy()
            cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
            cv2.imshow('Draw rectangle',image_copy)
    
    elif event ==  cv2.EVENT_LBUTTONUP:
        drawing = False
        rect_end = (x,y)
        cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
        cv2.imshow('Draw rectangle',image)

# %%
cv2.namedWindow('Draw rectangle')
cv2.setMouseCallback('Draw rectangle',draw_rectangle)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7, in draw_rectangle(event, x, y, flags, param)
#       5     rect_start = (x,y)
#       6 elif event ==cv2.EVENT_MOUSEMOVE:
# ----> 7     if drawing:
#       8         image_copy = image.copy()
#       9         cv2.rectangle(image_copy, rect_start, (x,y),(0,255,0),2)
#
# NameError: name 'drawing' is not defined
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 15, in draw_rectangle(event, x, y, flags, param)
#      13 drawing = False
#      14 rect_end = (x,y)
# ---> 15 cv2.rectangle(image_copy, rect_start, rect_end,(0,255,0),2)
#      16 cv2.imshow('Draw rectangle',image)
#
# UnboundLocalError: cannot access local variable 'image_copy' where it is not associated with a value
# -1

# %%
print(rect_start, rect_end)
# Out:
# (369, 278) (668, 514)

# %%
#print(img)

# %%
#print(img_gray)

# %%
import matplotlib.pyplot as plt
img_rgb[:,:,1] = img_rgb[:,:,1] +50
plt.imshow(img_rgb)

# %%
img3 = cv2.imread('images/girl.jpeg')

# %%
img3_sum = cv2.applyColorMap(img3, cv2.COLORMAP_SUMMER)
img3_ocean = cv2.applyColorMap(img3, cv2.COLORMAP_OCEAN)

# %%
cv2.imshow('image',img3_sum)
cv2.imshow('image2',img3_ocean)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:55cc5d18-d8b9-4058-86eb-5fc001e73b18.png)
